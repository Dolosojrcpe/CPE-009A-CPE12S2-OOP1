# %% [markdown]
# <a href="https://colab.research.google.com/github/Dolosojrcpe/CPE-009A-CPE12S2-OOP1/blob/main/Midterm_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 23

# %%
a = 5
for x in range(1, a +1):
   print("*" * x)
for y in range(a -1, 0, -1):
   print("*" * y)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# Question 24

# %%
a = 5
while a in range(1, a +1):
   print("*" * a)
if a in range(a -1, 0, -1):
   print("*" * a)
# Out:
# Streaming output truncated to the last 5000 lines.
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/Dolosojrcpe/CPE-009A-CPE12S2-OOP1/blob/main/Control_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("enter a number")
x = int(input())

if x>10:
    print("above ten, ")
    if x >20:
        print("and also above 20!")
        if x >30:
           print("and also above 30")
        else:
         print("below 30")
    else:
      print("below 20")
else:
 print("below 10")
# Out:
# enter a number

# %%
print("Enter a Grade: ")
grade = int(input())
if grade>=75:
  print("Passed")
elif grade==74:
    print("Remedial")
elif grade<-1:
    print("Not Accepted!")
else:
    print("failed")

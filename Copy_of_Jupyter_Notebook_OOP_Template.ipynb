# %% [markdown]
# <a href="https://colab.research.google.com/github/Dolosojrcpe/CPE-009A-CPE12S2-OOP1/blob/main/Copy_of_Jupyter_Notebook_OOP_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
#   <center><h4>  Activity No. and Title: Hands-on Activity 2.1 Literals and Variables </h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed**: 1-15-2026 |
# | **Section**: CpE12s2  | **Date Submitted:** |
# | **Student Name**: Andrew S. Doloso Jr.  | **Instructor's Name**: Engr. Maria Rizette Sayo |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   List item
# 2.   List item
#
# **Intended Learning Outcome:**
#
# 1.   List item
# 2.   List item
#
# **Discussion:**
#
# (put your discussions here)
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

# %% [markdown]
# **Supplementary Activity**:
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 50
# Prelim CS is:  85.5
# Enter Prelim Exam grade: 75
# Prelim Grade is:  80.25

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

MHOA = float(input("MIDTERM Hands-on Activity grade: "))
MQUIZ = float(input("MIDTERM Quiz grade: "))
MAS = float(input("MIDTERM Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("MIDTERM CS is: ", MCS)
MEX = float(input("MIDTERM Exam grade: "))
MG = (PG*(1/3)) + (2/3)*(MEX*.5+MCS*.5)
print("MIDTERM Grade is: ", "%.2f" % MG)

FHOA = float(input("FINAL Hands-on Activity grade: "))
FQUIZ = float(input("FINAL Quiz grade: "))
FAS = float(input("FINAL Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("FINAL CS is: ", FCS)
FEX = float(input("FINAL  Exam grade: "))
FG = (MG*(1/3)) + (2/3)*(FEX*.5+FCS*.5)
print("FINAL Grade is: ", "%.2f" % FG)
# Out:
# Enter Hands-on Activity grade: 95
# Enter Prelim Quiz grade: 95
# Enter Prelim Assignment grade: 98
# Prelim CS is:  95.6
# Enter Prelim Exam grade: 97
# Prelim Grade is:  96.30
# MIDTERM Hands-on Activity grade: 100
# MIDTERM Quiz grade: 98
# MIDTERM Assignment grade: 98
# MIDTERM CS is:  99.0
# MIDTERM Exam grade: 99
# MIDTERM Grade is:  98.10
# FINAL Hands-on Activity grade: 85
# FINAL Quiz grade: 89
# FINAL Assignment grade: 86
# FINAL CS is:  86.4
# FINAL  Exam grade: 85
# FINAL Grade is:  89.83

# %%
1STUDENT = (input("Enter Name: "))
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

MHOA = float(input("MIDTERM Hands-on Activity grade: "))
MQUIZ = float(input("MIDTERM Quiz grade: "))
MAS = float(input("MIDTERM Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("MIDTERM CS is: ", MCS)
MEX = float(input("MIDTERM Exam grade: "))
MG = (PG*(1/3)) + (2/3)*(MEX*.5+MCS*.5)
print("MIDTERM Grade is: ", "%.2f" % MG)

FHOA = float(input("FINAL Hands-on Activity grade: "))
FQUIZ = float(input("FINAL Quiz grade: "))
FAS = float(input("FINAL Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("FINAL CS is: ", FCS)
FEX = float(input("FINAL  Exam grade: "))
FG = (MG*(1/3)) + (2/3)*(FEX*.5+FCS*.5)
print("FINAL Grade is: ", "%.2f" % FG)
# Out:
# Enter Hands-on Activity grade: 95
# Enter Prelim Quiz grade: 95
# Enter Prelim Assignment grade: 98
# Prelim CS is:  95.6
# Enter Prelim Exam grade: 97
# Prelim Grade is:  96.30
# MIDTERM Hands-on Activity grade: 100
# MIDTERM Quiz grade: 98
# MIDTERM Assignment grade: 98
# MIDTERM CS is:  99.0
# MIDTERM Exam grade: 99
# MIDTERM Grade is:  98.10
# FINAL Hands-on Activity grade: 85
# FINAL Quiz grade: 89
# FINAL Assignment grade: 86
# FINAL CS is:  86.4
# FINAL  Exam grade: 85
# FINAL Grade is:  89.83
